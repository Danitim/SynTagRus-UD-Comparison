# %%
# %load_ext autoreload
# %autoreload 2

from IPython.display import display
from src.utils import build_data_from_suffix

# %%
DATA = build_data_from_suffix("syntax", csv_dir="aligned")

# %%
from src.utils import save_inconsistency

save_inconsistency(DATA, "обст", ("obl:tmod", "obl"))

# %% [markdown]
# ### количест: nummod <-> nummod:gov
#
# OLD nummod -> 100_2011Lekarstva_ot_ustalosti
#
# NEW nummog:gov -> 103_2019Dvadtsat_let_defoltu

# %% [markdown]
# ### сравн-союзн: case <-> mark
#
# OLD mark -> 102_2003Chto_doktor_propisal
#
# NEW case -> 104_2019Zanimatelnaya_estetika

# %% [markdown]
# ### присвяз: xcomp <-> obl
#
# OLD obl -> 101_2007Gematologiya
#
# NEW xcomp -> 124_2019Pokhozhdeniya_ryadovogo_podpisanta

# %% [markdown]
# ### присвяз: xcomp <-> obl
#
# Ошибка модели

# %% [markdown]
# ### обст: obl:tmod <-> obl
#
# OLD obl ->
#
# NEW obl ->
